# %% [markdown]
# <a href="https://colab.research.google.com/github/mllrosa/prova_modulo_3/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy._core.fromnumeric import shape
import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# pd.set_option("display.max_rows", 30)
# pd.set_option("display.max_columns", 30)
# print("Ambiente pronto.")

# Questão 1) ok Importe o arquivo CSV e crie um DataFrame chamado df
dados = pd.read_csv("/content/avaliacao_empresa.csv")
df = pd.DataFrame(dados)

# Questão 2) ok Mostre os 5 primeiros elementos do DataFrame.
# df.head(5)

# Questão 3) ok Exiba as informações gerais do DataFrame (tipos de dados e nulos).
# df.info()

# Questão 4) Mostre o formato (linhas, colunas) e a lista de colunas do DataFrame. ----
# df.shape()
# df.columns

# Questão 5) Exiba as estatísticas descritivas das colunas numéricas (média, min, max, etc.).


# Questão 6) ok Selecione apenas as colunas nome e departamento e mostre as 5 primeiras linhas.
# df[['nome', 'departamento']].head()

# Questão 7) ok Filtre os registros do turno 'Noite' e conte quantos registros existem.
# df.value_counts([df['turno']=='Noite'])
# df[df['turno']=='Noite'].value_counts()

# Questão 8) ok O código abaixo converte as datas de texto para data e em seguida cria uma coluna mês para os dados.
# Mostre as 5 primeiras linhas de df[['data','mes']].
df['data']=pd.to_datetime(df['data'],errors='coerce')
df['mes']=df['data'].dt.to_period('M').astype(str)
df[['data','mes']].head()


# Questão 9) O código abaixo agrupa e soma os valores por mes no DataFrame fat.
fat = df.groupby('mes',as_index=False)['faturamento'].sum().max()

# Mostre os 3 meses com maior faturamento.


# Questão 10) ok Calcule a média de salário por departamento e mostre em ordem decrescente. -----
# df.groupby('departamento',as_index=False)['salario'].mean().sort_values('salario',ascending=False)

# %%
import pandas as pd

# Questão 1) ok Importe o arquivo CSV e crie um DataFrame chamado df
dados = pd.read_csv("/content/avaliacao_empresa.csv")
df = pd.DataFrame(dados)
df
# Out:
#     id_funcionario      nome departamento  turno     cidade        data  \
# 0                2     Bruno    Operacoes  Tarde   Campinas  2025-01-01
# 1                3     Carla           TI  Noite  Sao Paulo  2025-01-08
# 2                4     Diego       Vendas  Manha   Campinas  2025-01-15
# 3                5    Elaine    Operacoes  Tarde  Sao Paulo  2025-01-22
# 4                6     Fabio           TI  Noite   Campinas  2025-01-29
# 5                7   Giovana       Vendas  Manha  Sao Paulo  2025-02-05
# 6                8  Henrique    Operacoes  Tarde   Campinas  2025-02-12
# 7                9      Iris           TI  Noite  Sao Paulo  2025-02-19
# 8               10      Joao       Vendas  Manha   Campinas  2025-02-26
# 9               11     Karen    Operacoes  Tarde  Sao Paulo  2025-03-05
# 10              12     Lucas           TI  Noite   Campinas  2025-03-12
# 11              13    Marina       Vendas  Manha  Sao Paulo  2025-03-19
# ...

# %%
import pandas as pd
dados = pd.read_csv("/content/avaliacao_empresa.csv")
df = pd.DataFrame(dados)

# Questão 2) ok Mostre os 5 primeiros elementos do DataFrame.
df.head(5)
# Out:
#    id_funcionario    nome departamento  turno     cidade        data  \
# 0               2   Bruno    Operacoes  Tarde   Campinas  2025-01-01
# 1               3   Carla           TI  Noite  Sao Paulo  2025-01-08
# 2               4   Diego       Vendas  Manha   Campinas  2025-01-15
# 3               5  Elaine    Operacoes  Tarde  Sao Paulo  2025-01-22
# 4               6   Fabio           TI  Noite   Campinas  2025-01-29
#
#    vendas_qtd  ticket_medio  faturamento     custo     lucro  \
# 0          56         975.0      54600.0  41435.15  13164.85
# 1          50         415.0      20750.0  10791.38   9958.62
# 2          55         107.0       5885.0   4287.17   1597.83
# 3          11         755.0       8305.0   4328.67   3976.33
# 4          44         456.0      20064.0  11597.60   8466.40
#
#    horas_trabalhadas  salario
# 0                166     8086
# 1                142     8703
# 2                130     8221
# 3                147     4954
# ...

# %%
import pandas as pd
dados = pd.read_csv("/content/avaliacao_empresa.csv")
df = pd.DataFrame(dados)

# Questão 3) ok Exiba as informações gerais do DataFrame (tipos de dados e nulos).
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_funcionario     26 non-null     int64
#  1   nome               26 non-null     object
#  2   departamento       26 non-null     object
#  3   turno              26 non-null     object
#  4   cidade             26 non-null     object
#  5   data               26 non-null     object
#  6   vendas_qtd         26 non-null     int64
#  7   ticket_medio       26 non-null     float64
#  8   faturamento        26 non-null     float64
#  9   custo              26 non-null     float64
#  10  lucro              26 non-null     float64
#  11  horas_trabalhadas  26 non-null     int64
#  12  salario            26 non-null     int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 2.8+ KB

# %%
import pandas as pd
dados = pd.read_csv("/content/avaliacao_empresa.csv")
df = pd.DataFrame(dados)

# Questão 4) Mostre o formato (linhas, colunas) e a lista de colunas do DataFrame. ----
# df.shape()
df.columns,df.shape

####
# Out:
# (Index(['id_funcionario', 'nome', 'departamento', 'turno', 'cidade', 'data',
#         'vendas_qtd', 'ticket_medio', 'faturamento', 'custo', 'lucro',
#         'horas_trabalhadas', 'salario'],
#        dtype='object'),
#  (26, 13))

# %%
import pandas as pd
dados = pd.read_csv("/content/avaliacao_empresa.csv")
df = pd.DataFrame(dados)

# Questão 5) Exiba as estatísticas descritivas das colunas numéricas (média, min, max, etc.).

df[['vendas_qtd','horas_trabalhadas', 'salario']].mean()
# Out:
# vendas_qtd             36.230769
# horas_trabalhadas     161.384615
# salario              6528.846154
# dtype: float64

# %%
import pandas as pd
dados = pd.read_csv("/content/avaliacao_empresa.csv")
df = pd.DataFrame(dados)

# Questão 5) Exiba as estatísticas descritivas das colunas numéricas (média, min, max, etc.).
df[['vendas_qtd','horas_trabalhadas', 'salario']].min()
# Out:
# vendas_qtd              7
# horas_trabalhadas     121
# salario              3274
# dtype: int64

# %%
import pandas as pd
dados = pd.read_csv("/content/avaliacao_empresa.csv")
df = pd.DataFrame(dados)

# Questão 5) Exiba as estatísticas descritivas das colunas numéricas (média, min, max, etc.).
df[['vendas_qtd','horas_trabalhadas', 'salario']].max()
# Out:
# vendas_qtd             57
# horas_trabalhadas     199
# salario              9297
# dtype: int64

# %%
import pandas as pd
dados = pd.read_csv("/content/avaliacao_empresa.csv")
df = pd.DataFrame(dados)

# Questão 6) ok Selecione apenas as colunas nome e departamento e mostre as 5 primeiras linhas.
df[['nome', 'departamento']].head()
# Out:
#      nome departamento
# 0   Bruno    Operacoes
# 1   Carla           TI
# 2   Diego       Vendas
# 3  Elaine    Operacoes
# 4   Fabio           TI

# %%
import pandas as pd
dados = pd.read_csv("/content/avaliacao_empresa.csv")
df = pd.DataFrame(dados)

# Questão 7) ok Filtre os registros do turno 'Noite' e conte quantos registros existem.
df.value_counts([df['turno']=='Noite'])
# df[df['turno']=='Noite'].value_counts()
# Out:
# turno
# False    17
# True      9
# Name: count, dtype: int64

# %%
import pandas as pd
dados = pd.read_csv("/content/avaliacao_empresa.csv")
df = pd.DataFrame(dados)

# Questão 8) ok O código abaixo converte as datas de texto para data e em seguida cria uma coluna mês para os dados.
# Mostre as 5 primeiras linhas de df[['data','mes']].
df['data']=pd.to_datetime(df['data'],errors='coerce')
df['mes']=df['data'].dt.to_period('M').astype(str)
df[['data','mes']].head()
# Out:
#         data      mes
# 0 2025-01-01  2025-01
# 1 2025-01-08  2025-01
# 2 2025-01-15  2025-01
# 3 2025-01-22  2025-01
# 4 2025-01-29  2025-01

# %%
import pandas as pd

dados = pd.read_csv("/content/avaliacao_empresa.csv")
df = pd.DataFrame(dados)



df['data']=pd.to_datetime(df['data'],errors='coerce')
df['mes']=df['data'].dt.to_period('M').astype(str)
# df[['data','mes']]

# Questão 9) O código abaixo agrupa e soma os valores por mes no DataFrame fat.

# fat = df.groupby('mes',as_index=False)['faturamento'].sum()


df.groupby('mes',as_index=False)['faturamento'].max().head(3)
# fat = df.groupby(['mes'],as_index=False)['faturamento'].max().head(3)
# df.groupby('departamento',as_index=False)['salario'].mean().sort_values('salario',ascending=True)
# Out:
#        mes  faturamento
# 0  2025-01      54600.0
# 1  2025-02      41753.0
# 2  2025-03      67816.0

# %%
import pandas as pd
dados = pd.read_csv("/content/avaliacao_empresa.csv")
df = pd.DataFrame(dados)

# Questão 10) ok Calcule a média de salário por departamento e mostre em ordem decrescente. -----
df.groupby('departamento',as_index=False)['salario'].mean().sort_values('salario',ascending=True)
# Out:
#   departamento      salario
# 0    Operacoes  6239.111111
# 2       Vendas  6554.875000
# 1           TI  6795.444444
